# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
spectras = pd.read_xml('XP_SAMPLED-Gaia DR3 450113435913489792.xml')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 spectras = pd.read_xml('XP_SAMPLED-Gaia DR3 450113435913489792.xml')
#
# File ~/.conda/envs/my_enviroment/lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/.conda/envs/my_enviroment/lib/python3.10/site-packages/pandas/io/xml.py:938, in read_xml(path_or_buffer, xpath, namespaces, elems_only, attrs_only, names, encoding, parser, stylesheet, compression, storage_options)
#     738 @deprecate_nonkeyword_arguments(
# ...

# %%
display(spectras)
# Out:
#                source_id          solution_id  bp_basis_function_id  \
# 0    2216195157578923136  4545469030156206080                    56
# 1     207878448651512704  4545469030156206081                    56
# 2     425601748322126976  4545469030156206080                    56
# 3     458454606008605312  4545469030156206080                    56
# 4     524114210600113792  4545469030156206080                    56
# ..                   ...                  ...                   ...
# 384  3026472417650160128  4545469030156206080                    56
# 385  1988532650757749376  4545469030156206081                    56
# 386  1898657883100188544  4545469030156206080                    56
# 387  1932278646577186688  4545469030156206080                    56
# 388   513993584023087872  4545469030156206080                    56
#
#      bp_degrees_of_freedom  bp_n_parameters  bp_n_measurements  \
# 0                      902               55                957
# ...
