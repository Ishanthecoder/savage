# %%
'''This cell imports pandas and the CSV file contiang the data that needs to be sorted and stores it as 'ctf' 

Genral note: This note book was created as a simplified verion of the filter interface notebook and carried over variable names from that project '''

import pandas as pd


pd.set_option("display.max_rows", None, "display.max_columns", None)

ctf = pd.read_csv ('coarse_table_full.csv')

        
print ("\nImport Complete\n")
# Out:
# Import Complete

# %%
'''This cell allows for easy modification to the search parameters category (Cat1) and search term (searchTerm1), which line 8 uses as inputs to filter ctf creating a new array containing only the indexes that meet the parameters called ctf2. 

In the orignal porject the code would promt the user to input these values'''
type(ctf)

Cat1 = "Class"#input category. this will work will work for both the string coloumns, Name and Class.   

searchTerm1 = "EM|Cool"

ctf2 = ctf.loc[ctf[Cat1].str.contains(searchTerm1)]
print (ctf2)
# Out:
#                                  Name          RA        Dec Class       Gmag
# 39            2MASS J00450373-7304508   11.265665 -73.080755  Cool  14.022185
# 104          WISE J005302.37-722955.6   13.259917 -72.498816  Cool  13.778352
# 123          WISE J005352.82-713757.4   13.470115 -71.632624  Cool  13.336357
# 180                          SkKM 181   14.729494 -72.552078  Cool  13.812414
# 212    SSTISAGEMA J010416.94-721423.5   16.070632 -72.239879  Cool  14.049083
# 262    SSTISAGEMA J012150.98-733740.9   20.462377 -73.628039  Cool  14.290894
# 285                          HV  2231   22.606365 -73.311424  Cool  13.335501
# 413                   TYC 3740-1791-1   67.040642  56.984493    EM  10.764656
# 430          WISE J043726.29-734942.3   69.359553 -73.828417  Cool  14.289128
# 441          OGLE BRIGHT-LMC-MISC-545   70.928847 -67.782091  Cool  13.231667
# 520          OGLE BRIGHT-LMC-MISC-169   72.947113 -69.323482  Cool  12.310104
# 552          WISE J045342.48-671617.5   73.427057 -67.271539  Cool  13.692883
# 573          WISE J045451.56-670203.9   73.714861 -67.034497    EM  14.046777
# 605          WISE J045550.56-695807.0   73.960641 -69.968616    EM  13.954285
# 607          WISE J045557.54-702100.5   73.989794 -70.350165  Cool  13.473413
# 620   {[KWV2015]} J045626.51-692350.6   74.110622 -69.397408  Cool  12.471458
# 642          WISE J045655.01-693312.0   74.229278 -69.553337  Cool  13.093004
# 654          WISE J045719.13-673047.0   74.329243 -67.513090    EM  14.631564
# 698          WISE J045846.54-670533.4   74.693902 -67.092646  Cool  14.072169
# 746          WISE J050102.45-680240.0   75.260278 -68.044466  Cool  13.523217
# 754                 MACHO  23.3422.13   75.355309 -70.669100  Cool  13.625755
# 756          WISE J050128.62-701120.2   75.369061 -70.188978    EM  13.878529
# 777           2MASS J05023010-6954046   75.625582 -69.901269  Cool  15.762985
# 807                 MACHO  53.3728.12   75.850978 -66.381139  Cool  13.267777
# 808          WISE J050324.56-662302.8   75.852395 -66.384159  Cool  13.450168
# 836          WISE J050417.01-662545.7   76.070946 -66.429380  Cool  14.001377
# 853          WISE J050451.37-714753.0   76.214018 -71.798064  Cool  13.728100
# 859           2MASS J05045770-6854047   76.240483 -68.901273  Cool  14.652910
# 877           2MASS J05053752-6854246   76.406413 -68.906809  Cool  14.796982
# 887          WISE J050555.12-663101.8   76.479748 -66.517142  Cool  14.124759
# 906          OGLE BRIGHT-LMC-MISC-378   76.637539 -68.362507  Cool  13.428046
# 936          WISE J050733.38-683117.8   76.889106 -68.521661  Cool  13.790269
# 956           2MASS J05083701-6944292   77.154339 -69.741506  Cool  15.673445
# 962          WISE J050911.17-655205.7   77.296539 -65.868256  Cool  13.216533
# ctf3step = [ctf3_1,ctf3_2]
# ctf3 = pd.concat(ctf3step)
#generate a array of which indexes meet the boleean conditon called ctf3 with index numbers from ctf2 
print (ctf3_1)

#ctf3[ctf3].index.values
targetStarsIndex1 = [*filter(ctf3_1.get, ctf3_1.index)]
targetStarsIndex2 = [*filter(ctf3_2.get, ctf3_2.index)]


ctfFinal1 = ctf2.loc[targetStarsIndex1]
ctfFinal2 = ctf2.loc[targetStarsIndex2]
ctf3step = [ctfFinal2,ctfFinal1]
ctfFinal = pd.concat(ctf3step)
display(ctfFinal)
# Out:
# 39      False
# 104     False
# 123     False
# 180     False
# 212     False
# 262     False
# 285     False
# 413      True
# 430     False
# 441     False
# 520     False
# 552     False
# 573     False
# 605     False
# 607     False
# 620     False
# 642     False
# 654     False
# 698     False
# 746     False
# 754     False
# 756     False
# 777     False
# 807     False
# 808     False
# 836     False
# 853     False
# 859     False
# 877     False
# 887     False
# 906     False
# 936     False
# 956     False
# 962     False
# 967     False
# 989     False
# 1024    False
# 1035    False
# 1054    False
# 1078    False
# 1083    False
# 1192    False
# 1213    False
# 1255    False
# 1283    False
# 1363    False
# 1406    False
# 1423    False
# 1462    False
# 1494    False
# 1500    False
# 1502    False
# 1507    False
# 1540    False
# 1558    False
# 1594    False
# 1597    False
# 1629    False
# 1678    False
# 1681    False
# 1718    False
# 1817    False
# 1827    False
# 1828    False
# 1831    False
# 1832    False
# 1834    False
# 1863    False
# 1908    False
# 2344    False
# 2379    False
# 2382    False
# 2440    False
# 2484    False
# 2494     True
# 2516     True
# 2525     True
# Name: Dec, dtype: bool
#                           Name          RA        Dec Class       Gmag
# 413            TYC 3740-1791-1   67.040642  56.984493    EM  10.764656
# 2494  WISE J185608.58-163255.1  284.035758 -16.548670  Cool  12.038886
# 2516  WISE J194127.64+385155.3  295.365206  38.865364  Cool  12.327266
# 2525            TYC 2670-214-1  299.608643  31.811638    EM  11.336642
# 413            TYC 3740-1791-1   67.040642  56.984493    EM  10.764656
# 2494  WISE J185608.58-163255.1  284.035758 -16.548670  Cool  12.038886
# 2516  WISE J194127.64+385155.3  295.365206  38.865364  Cool  12.327266
# 2525            TYC 2670-214-1  299.608643  31.811638    EM  11.336642

# %%
ctfFinal.to_csv('PizzaTest.csv',index = False, na_rep="NAN!")

tsi = pd.read_csv ('PizzaTest.csv')
tsi
#type (tsi)
# Out:
#                        Name          RA        Dec Class       Gmag
# 0           TYC 3740-1791-1   67.040642  56.984493    EM  10.764656
# 1  WISE J185608.58-163255.1  284.035758 -16.548670  Cool  12.038886
# 2  WISE J194127.64+385155.3  295.365206  38.865364  Cool  12.327266
# 3            TYC 2670-214-1  299.608643  31.811638    EM  11.336642
# 4           TYC 3740-1791-1   67.040642  56.984493    EM  10.764656
# 5  WISE J185608.58-163255.1  284.035758 -16.548670  Cool  12.038886
# 6  WISE J194127.64+385155.3  295.365206  38.865364  Cool  12.327266
# 7            TYC 2670-214-1  299.608643  31.811638    EM  11.336642

# %%
tsi2= pd.read_csv ('COSMOS_Hot_Bright_Targets_Interest_Order - cosmos_all_targets_decimal.csv')
tsi2
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-45-95eb87826d25> in <module>
# ----> 1 tsi2= pd.read_csv ('COSMOS_Hot_Bright_Targets_Interest_Order - cosmos_all_targets_decimal.csv')
#       2 tsi2
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     450
#     451     # Create the parser.
# --> 452     parser = TextFileReader(fp_or_buf, **kwds)
#     453
#     454     if chunksize or iterator:
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     944             self.options["has_index_names"] = kwds["has_index_names"]
#     945
# --> 946         self._make_engine(self.engine)
#     947
#     948     def close(self):
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1176     def _make_engine(self, engine="c"):
#    1177         if engine == "c":
# -> 1178             self._engine = CParserWrapper(self.f, **self.options)
#    1179         else:
#    1180             if engine == "python":
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    2006         kwds["usecols"] = self.usecols
#    2007
# -> 2008         self._reader = parsers.TextReader(src, **kwds)
#    2009         self.unnamed_cols = self._reader.unnamed_cols
#    2010
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'COSMOS_Hot_Bright_Targets_Interest_Order - cosmos_all_targets_decimal.csv'
