# %%
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
import pylab as lab
print ("import done")
# Out:
# import done

# %%
wave1,flux1,_ = np.genfromtxt('StarBlindSample4.txt',unpack=True)
wave2,flux2,_ = np.genfromtxt('StarBlindSample5.txt',unpack=True)
wave3,flux3,_ = np.genfromtxt('V367Cyg.txt',unpack=True)

# %%
plt.title("Sample 4") 
plt.xlabel("Wave") 
plt.ylabel("Flux") 
plt.plot(wave1,flux1) 
#plt.xlim(340,700)
plt.show()

plt.title("Sample 5") 
plt.xlabel("Wave") 
plt.ylabel("Flux") 
plt.plot(wave2,flux2) 
#plt.xlim(340,700)
plt.show()
plt.title("V367Cyg") 
plt.xlabel("Wave") 
plt.ylabel("Flux") 
plt.plot(wave3,flux3) 
#plt.xlim(340,700)
plt.show()

# %%
xminInput = (input("Enter x min for range you wnat to focus on (see x axis for range)"))
xmaxInput = (input("Enter x max for range you want to focus on (see x axis for range)"))
yminInput = (input("Enter y min for range you want to focus on (0 to 1.6)"))
ymaxInput = (input("Enter y min for range you want to focus on (0 to 1.6)"))
xmin = float(xminInput)
xmax = float(xmaxInput)
ymin = float(yminInput)
ymax = float(ymaxInput)
# Out:
# Enter x min for range you wnat to focus on (see x axis for range)840
# Enter x max for range you want to focus on (see x axis for range)860
# Enter y min for range you want to focus on (0 to 1.6)0
# Enter y min for range you want to focus on (0 to 1.6)1.4

# %%
x = wave2
y = flux2
lab.plot(x, y)
lab.axhline(0, color="black")
lab.axvline(0, color="black")
lab.ylim(0,ymax)
lab.xlim(xmin,xmax)

#lab.xlim(840,860)

lab.show()

print ("? star, V367Cyg")
# Out:
# ? star, V367Cyg

# %%
x = wave2
y = flux2
lab.plot(x, y)
lab.axhline(0, color="black")
lab.axvline(0, color="black")
lab.ylim(0,ymax)
#lab.xlim(xmin,xmax)

lab.xlim(840,860)

lab.show()

print ("? star, V367Cyg")
# Out:
# ? star, V367Cyg

# %%
x = wave1
y = flux1
lab.plot(x, y)
lab.axhline(0, color="black")
lab.axvline(0, color="black")
lab.ylim(ymin,ymax)
lab.xlim(xmin,xmax)


lab.show()

print ("? star, ?")
# Out:
# ? star, ?

# %%
#OBAFGKM
