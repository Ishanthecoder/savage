# %%
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
import pylab as lab
print ("import done")
# Out:
# import done

# %%
wave1,flux1,_ = np.genfromtxt('StarBlindSample4.txt',unpack=True)
wave2,flux2,_ = np.genfromtxt('StarBlindSample5.txt',unpack=True)
wave3,flux3,_ = np.genfromtxt('V367Cyg.txt',unpack=True)

# %%
plt.title("Sample 4") 
plt.xlabel("Wave") 
plt.ylabel("Flux") 
plt.plot(wave1,flux1) 
#plt.xlim(340,700)
plt.show()

plt.title("Sample 5") 
plt.xlabel("Wave") 
plt.ylabel("Flux") 
plt.plot(wave2,flux2) 
#plt.xlim(340,700)
fig, axes = plt.subplots(2, 1, figsize=(16, 10),dpi=300)
axes[0.show()
plt.title("V367Cyg") 
plt.xlabel("Wave") 
plt.ylabel("Flux") 
plt.plot(wave3,flux3) 
#plt.xlim(340,700)
plt.show()

# %%
# xminInput = (input("Enter x min for range you wnat to focus on (see x axis for range)"))
# xmaxInput = (input("Enter x max for range you want to focus on (see x axis for range)"))
# yminInput = (input("Enter y min for range you want to focus on (0 to 1.6)"))
# ymaxInput = (input("Enter y min for range you want to focus on (0 to 1.6)"))
# xmin = float(xminInput)
# xmax = float(xmaxInput)
# ymin = float(yminInput)
# ymax = float(ymaxInput)

xmin = float(640)
xmax = float(670)
ymin = float(0)
ymax = float(1.6)

# %%
x = wave2
y = flux2
lab.plot(x, y)
lab.axhline(0, color="black")
lab.axvline(0, color="black")
#lab.ylim(ymin,ymax)
lab.xlim(xmin,xmax)

#lab.xlim(840,860)

lab.show()

print ("? star, V367Cyg")
# Out:
# ? star, V367Cyg

# %%
x = wave1
y = flux1
lab.plot(x, y)
lab.axhline(0, color="black")
lab.axvline(0, color="black")
lab.ylim(ymin,ymax)
lab.xlim(xmin,xmax)


lab.show()

print ("? star, ? \n Balmer line H alpha 656.3 \n He, probably not there \n Balmer H gamma 434.8 \n G band 430.8 \n Fe 432.5 \n TiO look like bites")
# Out:
# ? star, ?
#  Balmer line H alpha 656.3
#  He, probably not there
#  Balmer H gamma 434.8
#  G band 430.8
#  Fe 432.5
#  TiO look like bites

# %%
x = wave1
y = flux1
lab.plot(x, y)
lab.axhline(0, color="black")
lab.axvline(0, color="black")
lab.ylim(0,1.5)
#lab.xlim(xmin,xmax)

lab.xlim(400.8,425)

lab.show()

print ("? star, V367Cyg")
# Out:
# ? star, V367Cyg

# %%
#OBAFGKM
