# %%
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
import pylab as lab
print ("import done")
# Out:
# import done

# %%
wave,flux,_ = np.genfromtxt('StarBlindSample2.txt',unpack=True)

# %%
plt.title("Test Plot") 
plt.xlabel("Wave") 
plt.ylabel("Flux") 
plt.plot(wave,flux) 
#plt.xlim(340,700)
plt.show()

# %%
x = wave
y = flux
lab.plot(x, y)
lab.axhline(0, color="black")
lab.axvline(0, color="black")
lab.ylim(-0,1.4)
lab.xlim(430,460)


lab.show()

# %%
print ("A star, eta Leo")
# Out:
# A star, eta Leo
