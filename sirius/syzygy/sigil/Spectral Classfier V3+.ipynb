# %%
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
import pylab as lab
import sys
# from specutils import Spectrum1D
# import astropy.units as u
# from specutils.manipulation import (box_smooth, gaussian_smooth, trapezoid_smooth)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-12-5446445a8b1b> in <module>
#       4 import pylab as lab
#       5 import sys
# ----> 6 from specutils import Spectrum1D
#       7 import astropy.units as u
#       8 from specutils.manipulation import (box_smooth, gaussian_smooth, trapezoid_smooth)
#
# ImportError: cannot import name 'Spectrum1D' from 'specutils' (unknown location)

# %%
def All_Charts(wave,flux):#0
    #This is all the charts
    #TiO Lines
    fig, axes = plt.subplots(17, 1, figsize=(16, 10),dpi=300)
    axes[0].set_title("Full Range, Zoomed Out)")
    axes[0].set_xlabel("Wave") 
    axes[0].set_ylabel("Flux") 
    axes[0].plot(wave,flux)
    #axes[0].set_xlim(355,1043)
    axes[0].axvline(x=1043,color="darkviolet",linewidth=0.5,ls="dashed")
    plt.tight_layout()
    axes[1].set_title("TiO Lines (Zoomed In Range)")
    axes[1].set_xlabel("Wave") 
    axes[1].set_ylabel("Flux") 
    axes[1].plot(wave,flux)
    axes[1].set_xlim(355,1043)
    axes[1].axvline(x=1043,color="darkviolet",linewidth=0.75,ls="dashed")
    #CaTriplet
    axes[2].set_title("Calcium Triplet (All)")
    axes[2].set_xlabel("Wave") 
    axes[2].set_ylabel("Flux") 
    axes[2].plot(wave,flux) 
    axes[2].set_xlim(835,880)
    axes[2].axvline(x=849.8,color="red",linewidth=0.5,ls="dashed")
    axes[2].axvline(x=854.2,color="forestgreen",linewidth=0.5,ls="dashed")
    axes[2].axvline(x=866.2,color="royalblue",linewidth=0.5,ls="dashed")
    axes[3].set_title("Calcium Triplet (849.8)")
    axes[3].set_xlabel("Wave") 
    axes[3].set_ylabel("Flux") 
    axes[3].plot(wave,flux) 
    axes[3].set_xlim(844.8,854.8)
    axes[3].axvline(x=849.8,color="darkviolet",linewidth=0.5,ls="dashed")
    axes[3].set_title("Calcium Triplet (854.2)")
    axes[3].set_xlabel("Wave") 
    axes[3].set_ylabel("Flux") 
    axes[3].plot(wave,flux) 
    axes[3].set_xlim(849.2,859.2)
    axes[3].axvline(x=854.2,color="darkviolet",linewidth=0.5,ls="dashed")
    axes[4].set_title("Calcium Triplet(866.2)")
    axes[4].set_xlabel("Wave") 
    axes[4].set_ylabel("Flux") 
    axes[4].plot(wave,flux) 
    axes[4].set_xlim(861.2,871.2)
    axes[4].axvline(x=866.2,color="darkviolet",linewidth=0.5,ls="dashed")
    #Balmer Line
    axes[5].set_title("Balmer Lines (Zoomed Out)")
    axes[5].set_xlabel("Wave") 
    axes[5].set_ylabel("Flux") 
    axes[5].plot(wave,flux) 
    axes[5].set_xlim(616,696)
    axes[5].axvline(x=656.3,color="darkviolet",linewidth=0.5,ls="dashed")
    axes[6].set_title("Balmer Line H Alpha [636,676]")
    axes[6].set_xlabel("Wave") 
    axes[6].set_ylabel("Flux") 
    axes[6].plot(wave,flux) 
    axes[6].set_xlim(636,676)
    axes[7].axvline(x=656.3,color="darkviolet",linewidth=0.5,ls="dashed")
    axes[7].set_title("Balmer Line H Alpha [646,666]")
    axes[7].set_xlabel("Wave") 
    axes[7].set_ylabel("Flux") 
    axes[7].plot(wave,flux) 
    axes[7].axvline(x=656.3,color="darkviolet",linewidth=0.5,ls="dashed")
    axes[7].set_xlim(646,666)
    plt.tight_layout()
    plt.show()
    
    print ("Preparing to run induvidual tests")
    
def TiO_Line_Test(wave,flux):#I
    #content 
    #All no limit, [355,1043]
    #TiO Line Test Block
    #takes wave and flux, returns if TiO line are present or not  
    x = wave
    y = flux

    fig, axes = plt.subplots(2, 1, figsize=(16, 10),dpi=300)
    axes[0].set_title("TiO Lines (Zoomed Out)")
    axes[0].set_xlabel("Wave") 
    axes[0].set_ylabel("Flux") 
    axes[0].plot(wave,flux)
    #axes[0].set_xlim(355,1043)
    axes[0].axvline(x=1043,color="darkviolet",linewidth=0.5,ls="dashed")
    plt.tight_layout()
    axes[1].set_title("TiO Lines (Zoomed In)")
    axes[1].set_xlabel("Wave") 
    axes[1].set_ylabel("Flux") 
    axes[1].plot(wave,flux)
    axes[1].set_xlim(355,1043)
    axes[1].axvline(x=1043,color="darkviolet",linewidth=0.75,ls="dashed")
    plt.tight_layout()
    
    plt.show()
    

    varTioLines =(input("Are TiO lines present (Hint: look for bites missing)? Yes/No"))
    global TiOLines
    if varTioLines == "No" :
        TiOLines = False
        print ("Cool! Now let's take a look at the Calcium Triplet...")

    if varTioLines == "Yes":
        TiOLines = True
        print("Huh, are you sure? Lets look at the Calcium Triplet just to be safe!")
        #sys.exit ("End of program. Have a nice day!")
        
    print (TiOLines)
    
    print ("TiO Line Test Complete")
    
def Calcium_Triplet_Test(wave,flux):#II
    fig, axes = plt.subplots(4, 1, figsize=(16, 10),dpi=300)
    axes[0].set_title("Calcium Triplet (All)")
    axes[0].set_xlabel("Wave") 
    axes[0].set_ylabel("Flux") 
    axes[0].plot(wave,flux) 
    axes[0].set_xlim(835,880)
    axes[0].axvline(x=849.8,color="red",linewidth=0.5,ls="dashed")
    axes[0].axvline(x=854.2,color="forestgreen",linewidth=0.5,ls="dashed")
    axes[0].axvline(x=866.2,color="royalblue",linewidth=0.5,ls="dashed")
    axes[1].set_title("Calcium Triplet (849.8)")
    axes[1].set_xlabel("Wave") 
    axes[1].set_ylabel("Flux") 
    axes[1].plot(wave,flux) 
    axes[1].set_xlim(844.8,854.8)
    axes[1].axvline(x=849.8,color="darkviolet",linewidth=0.5,ls="dashed")
    axes[2].set_title("Calcium Triplet (854.2)")
    axes[2].set_xlabel("Wave") 
    axes[2].set_ylabel("Flux") 
    axes[2].plot(wave,flux) 
    axes[2].set_xlim(849.2,859.2)
    axes[2].axvline(x=854.2,color="darkviolet",linewidth=0.5,ls="dashed")
    axes[3].set_title("Calcium Triplet(866.2)")
    axes[3].set_xlabel("Wave") 
    axes[3].set_ylabel("Flux") 
    axes[3].plot(wave,flux) 
    axes[3].set_xlim(861.2,871.2)
    axes[3].axvline(x=866.2,color="darkviolet",linewidth=0.5,ls="dashed")
    plt.show()

    varCaTriplet =(input("Are the Calcium Triplet present? Yes/No"))
    global strongCaTriplet 
    if varCaTriplet == "Yes" :
        strongCaTriplet = True
        print ("Alright, it's probably a Cool star so expect balmer lines not to be dominant. It's likely a G, K or M star. If Balmmer lines are dominant It's probably an F star")
        
    else: 
        if varCaTriplet == "No" :
            strongCaTriplet = False
            print ("Hmmm, in that case this likley a Hot star in which case balmer lines are likey dominant. It is also likely not a G or K or M star and possibly an F star")

        else:
            #sys.exit ("Error, not a valid response. Pls resart program.")
            print ("Error, not a valid response. Pls resart program.")
    #content
    #All[835,880]; 849.8[844.8,854.8]; 854.2[849.2,859.2]; 866.2[861.2,871.2]
    #IV (Three (III) is (or will be) a logic test for elminating M stars, not an actual spectral test)
    print ("Calcium Triplet Test Complete")
def Balmer_Line_Presence_Test(wave,flux):#IV
    fig, axes = plt.subplots(3, 1, figsize=(16, 10),dpi=300)
    axes[0].set_title("Balmer Lines (Zoomed Out)")
    axes[0].set_xlabel("Wave") 
    axes[0].set_ylabel("Flux") 
    axes[0].plot(wave,flux) 
    axes[0].set_xlim(616,696)
    axes[0].axvline(x=656.3,color="darkviolet",linewidth=0.5,ls="dashed")
    axes[1].set_title("Balmer Line H Alpha [636,676]")
    axes[1].set_xlabel("Wave") 
    axes[1].set_ylabel("Flux") 
    axes[1].plot(wave,flux) 
    axes[1].set_xlim(636,676)
    axes[1].axvline(x=656.3,color="darkviolet",linewidth=0.5,ls="dashed")
    axes[2].set_title("Balmer Line H Alpha [646,666]")
    axes[2].set_xlabel("Wave") 
    axes[2].set_ylabel("Flux") 
    axes[2].plot(wave,flux) 
    axes[2].axvline(x=656.3,color="darkviolet",linewidth=0.5,ls="dashed")
    axes[2].set_xlim(646,666)
    plt.tight_layout()
    plt.show()

    varSBalmerLines =(input("Are the Balmer lines strong? Yes/No"))
    
        
    print ("Balmer Line Presence Test Complete")
    #content 
    #Z out: [616.0, 696.0]; Z in 1: [636.0, 676.0]; Z in 2: [646.0,666.0]
def Balmer_Line_Dominance_Test(wave,flux):#V
    varDBalmerLines =(input("Are the Balmer lines dominant? Yes/No"))
    global dominantBalmer
    global strongBalmer
    
    if varDBalmerLines == "No" :
        print ("Cool! Now that we figured that out, we need to determine if the G-band < Hγ! Zooming in to 434.8 and 430.8 angstroms")
        dominantBalmer = False 
    else: 
        if varDBalmerLines == "Yes" :
            dominantBalmer = True
            
            

    if varSBalmerLines == "No" :
        print ("Cool! Now that we figured that out, we need to determine if the G-band < Hγ! Zooming in to 434.8 and 430.8 angstroms")
        strongBalmer = False 
    print ("Balmer Line Dominance Test Complete")
    #content 
    #Z out: [616.0, 696.0]; Z in 1: [636.0, 676.0]; Z in 2: [646.0,666.0]
def GbandvsHγ_Test(wave,flux):#VI
    print ("Gband < Hγ Test Complete")
    #content 
def He_Test(wave,flux):#VII
    print ("He Test Complete")
    #content 
def HeII_Test(wave,flux):#IIX
    print ("HeII Test Complete")
    #content   
def HγvsFe_Test(wave,flux):#IX
    print ("Hγ < Fe Test Complete")
    #content

# %%
wave,flux,_ = np.genfromtxt('tyc2670_090721_merged-Copy1.txt',unpack=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-452f07dfab46> in <module>
# ----> 1 wave,flux,_ = np.genfromtxt('tyc2670_090721_merged-Copy1.txt',unpack=True)
#
# NameError: name 'np' is not defined

# %%
All_Charts(wave,flux)
